# %% [markdown]
# <a href="https://colab.research.google.com/github/palash116/FirstCode2025/blob/week_6/Week_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import the packages

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, confusion_matrix, classification_report,
    precision_score, recall_score, f1_score,
    roc_curve, roc_auc_score, auc
)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
import warnings
warnings.filterwarnings('ignore')
data = pd.read_csv('/content/drive/MyDrive/datasets/Breast_Cancer_Wisconsin_Dataset.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(f"Dataset loaded! We have data from {len(data)} real patients")
print(f"Each patient has {len(data.columns)-2} medical measurements")
# Out:
# Dataset loaded! We have data from 569 real patients
# Each patient has 31 medical measurements

# %% [markdown]
# # Prepare Data

# %%
# Convert diagnosis to numbers
data['diagnosis_numeric'] = data['diagnosis'].map({'M': 1, 'B': 0})

# %%
# Select only the most important features (make it simple!)
important_features = [
    'radius_mean',      # Size of tumor
    'perimeter_mean',
    'area_mean',        # Area of tumor
    'concavity_mean',
    'symmetry_mean',
    'fractal_dimension_mean',
    'radius_se',
    'texture_se',
    'area_se',
    'compactness_se'
]

# %%
# Create simple dataset
X = data[important_features]  # Patient measurements
y = data['diagnosis_numeric']  # Malignant (1) or Benign (0)

print(f"\nData prepared:")
print(f"X (measurements): {X.shape}")
print(f"y (diagnosis): {y.shape}")
# Out:
# Data prepared:
# X (measurements): (569, 10)
# y (diagnosis): (569,)

# %% [markdown]
# # Train and Test split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=20
)

print(f"Training: {len(X_train)} patients")
print(f"Testing:  {len(X_test)} patients")
display((X_train.head()))
# Out:
# Training: 455 patients
# Testing:  114 patients
#      radius_mean  perimeter_mean  area_mean  concavity_mean  symmetry_mean  \
# 412        9.397           59.75      268.8         0.03735         0.1274
# 461       27.420          186.90     2501.0         0.36350         0.2061
# 532       13.680           87.76      575.5         0.01752         0.1631
# 495       14.870           96.12      680.9         0.06824         0.1487
# 13        15.850          103.70      782.7         0.09938         0.1847
#
#      fractal_dimension_mean  radius_se  texture_se  area_se  compactness_se
# 412                 0.06724     0.1186      1.1820    6.802        0.026740
# 461                 0.05623     2.5470      1.3060  542.200        0.053740
# 532                 0.06155     0.2047      0.4801   17.250        0.007228
# 495                 0.05748     0.2323      1.6360   21.840        0.013710
# 13                  0.05338     0.4033      1.0780   36.580        0.031260

# %% [markdown]
# # Train with Decision Tree

# %% [markdown]
# ## For depth 3

# %%
model= DecisionTreeClassifier(
    max_depth=3,  # Keep it simple - not too complex
    random_state=20
)
print("Teaching model with training data...")
# Train the model
model.fit(X_train, y_train)
print(" training completed!")
# Out:
# Teaching model with training data...
#  training completed!

# %% [markdown]
# # For depth 4

# %%
model4 = DecisionTreeClassifier(
    max_depth=4,  # Keep it simple - not too complex
    random_state=20
)
print("Teaching model with training data...")
# Train the model
model4.fit(X_train, y_train)
print("training completed!")
# Out:
# Teaching model with training data...
# training completed!

# %% [markdown]
# ## For depth 5

# %%
model5 = DecisionTreeClassifier(
    max_depth=5,  # Keep it simple - not too complex
    random_state=20
)
print("Teaching model with training data...")
# Train the model
model5.fit(X_train, y_train)
print("training completed!")
# Out:
# Teaching model with training data...
# training completed!

# %% [markdown]
# ## For depth 7

# %%
model7 = DecisionTreeClassifier(
    max_depth=7,  # Keep it simple - not too complex
    random_state=20
)
print("Teaching model with training data...")
# Train the model
model7.fit(X_train, y_train)
print("training completed!")
# Out:
# Teaching model with training data...
# training completed!

# %% [markdown]
# ## For depth 6

# %%
model6 = DecisionTreeClassifier(
    max_depth=6,  # Keep it simple - not too complex
    random_state=20
)
print("Teaching model with training data...")
# Train the model
model6.fit(X_train, y_train)
print("training completed!")
# Out:
# Teaching model with training data...
# training completed!

# %% [markdown]
# # Test our predicted doctor

# %% [markdown]
# ## For depth 3

# %%
print("Now let's see how good our model doctor is...")

# Make predictions
predictions =model.predict(X_test)
prediction_probabilities =model.predict_proba(X_test) [:, 1]# Probability of malignant cancer (class 1)
print("Model made predictions for all test patients!")

# Calculate accuracy
accuracy = accuracy_score(y_test, predictions)
print(f"\nModel Accuracy: {accuracy:.3f} ({accuracy*100:.1f}%)")
if accuracy > 0.95:
    print("EXCELLENT! Our Fitted model is very accurate!")
elif accuracy > 0.90:
    print("GOOD! Our Fitted model performs well!")
elif accuracy > 0.80:
    print("OK! Our Fitted model is decent!")
else:
    print("Needs improvement...")
# Out:
# Now let's see how good our model doctor is...
# Model made predictions for all test patients!
#
# Model Accuracy: 0.868 (86.8%)
# OK! Our Fitted model is decent!

# %% [markdown]
# ## For depth 4

# %%
print("Now let's see how good our model doctor is...")

# Make predictions
predictions4 =model4.predict(X_test)
prediction_probabilities4 =model4.predict_proba(X_test) [:, 1]# Probability of malignant cancer (class 1)
print("Model made predictions for all test patients!")

# Calculate accuracy
accuracy4= accuracy_score(y_test, predictions4)
print(f"\nModel Accuracy: {accuracy4:.3f} ({accuracy4*100:.1f}%)")
if accuracy4 > 0.95:
    print("EXCELLENT! Our Fitted model is very accurate!")
elif accuracy4 > 0.90:
    print("GOOD! Our Fitted model performs well!")
elif accuracy4 > 0.80:
    print("OK! Our Fitted model is decent!")
else:
    print("Needs improvement...")
# Out:
# Now let's see how good our model doctor is...
# Model made predictions for all test patients!
#
# Model Accuracy: 0.886 (88.6%)
# OK! Our Fitted model is decent!

# %% [markdown]
# ## For depth 5

# %%
print("Now let's see how good our model doctor is...")

# Make predictions
predictions5 =model5.predict(X_test)
prediction_probabilities5 =model5.predict_proba(X_test) [:, 1]# Probability of malignant cancer (class 1)
print("Model made predictions for all test patients!")

# Calculate accuracy
accuracy5= accuracy_score(y_test, predictions5)
print(f"\nModel Accuracy: {accuracy5:.3f} ({accuracy5*100:.1f}%)")
if accuracy5 > 0.95:
    print("EXCELLENT! Our Fitted model is very accurate!")
elif accuracy5 > 0.90:
    print("GOOD! Our Fitted model performs well!")
elif accuracy5 > 0.80:
    print("OK! Our Fitted model is decent!")
else:
    print("Needs improvement...")
# Out:
# Now let's see how good our model doctor is...
# Model made predictions for all test patients!
#
# Model Accuracy: 0.912 (91.2%)
# GOOD! Our Fitted model performs well!

# %% [markdown]
# ## For depth 7

# %%
print("Now let's see how good our model doctor is...")

# Make predictions
predictions7=model7.predict(X_test)
prediction_probabilities7=model7.predict_proba(X_test) [:, 1]# Probability of malignant cancer (class 1)
print("Model made predictions for all test patients!")

# Calculate accuracy
accuracy7= accuracy_score(y_test, predictions7)
print(f"\nModel Accuracy: {accuracy7:.3f} ({accuracy7*100:.1f}%)")
if accuracy7 > 0.95:
    print("EXCELLENT! Our Fitted model is very accurate!")
elif accuracy7 > 0.90:
    print("GOOD! Our Fitted model performs well!")
elif accuracy7 > 0.80:
    print("OK! Our Fitted model is decent!")
else:
    print("Needs improvement...")
# Out:
# Now let's see how good our model doctor is...
# Model made predictions for all test patients!
#
# Model Accuracy: 0.921 (92.1%)
# GOOD! Our Fitted model performs well!

# %% [markdown]
# ## For depth 6

# %%
print("Now let's see how good our model doctor is...")

# Make predictions
predictions6=model6.predict(X_test)
prediction_probabilities10=model6.predict_proba(X_test) [:, 1]# Probability of malignant cancer (class 1)
print("Model made predictions for all test patients!")

# Calculate accuracy
accuracy6= accuracy_score(y_test, predictions6)
print(f"\nModel Accuracy: {accuracy6:.3f} ({accuracy6*100:.1f}%)")
if accuracy6 > 0.95:
    print("EXCELLENT! Our Fitted model is very accurate!")
elif accuracy6 > 0.90:
    print("GOOD! Our Fitted model performs well!")
elif accuracy6 > 0.80:
    print("OK! Our Fitted model is decent!")
else:
    print("Needs improvement...")
# Out:
# Now let's see how good our model doctor is...
# Model made predictions for all test patients!
#
# Model Accuracy: 0.912 (91.2%)
# GOOD! Our Fitted model performs well!

# %% [markdown]
# # Confusion Metrics

# %%
# Calculate confusion matrix
cm = confusion_matrix(y_test, predictions7)
print("Confusion Matrix (Mistake Analysis):")
print(cm)

print("\nHow to read Confusion Matrix:")
print(f"""
                 Predicted
              Benign   Malignant
Real Benign     {cm[0,0]}        {cm[0,1]}   ← {cm[0,1]} False Alarms (predicted malignant but was benign)
Real Malignant  {cm[1,0]}        {cm[1,1]}   ← {cm[1,0]} Missed Malignant (predicted benign but was malignant) ⚠️

✅ Correct Predictions: {cm[0,0] + cm[1,1]}
❌ Wrong Predictions: {cm[0,1] + cm[1,0]}

⚠️ DANGER: Missing malignant cancer ({cm[1,0]} cases) is more dangerous than false alarms ({cm[0,1]} cases)
""")
# Out:
# Confusion Matrix (Mistake Analysis):
# [[63  3]
#  [ 6 42]]
#
# How to read Confusion Matrix:
#
#                  Predicted
#               Benign   Malignant
# Real Benign     63        3   ← 3 False Alarms (predicted malignant but was benign)
# Real Malignant  6        42   ← 6 Missed Malignant (predicted benign but was malignant) ⚠️
#
# ✅ Correct Predictions: 105
# ❌ Wrong Predictions: 9
#
# ⚠️ DANGER: Missing malignant cancer (6 cases) is more dangerous than false alarms (3 cases)

# %%
# Create beautiful confusion matrix plot
plt.figure(figsize=(10, 4))
# Confusion Matrix Plot
plt.subplot(1, 2, 1)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Benign', 'Malignant'],
            yticklabels=['Benign', 'Malignant'],
            cbar_kws={'label': 'Number of Patients'})
plt.title('Confusion Matrix\n(Model Mistakes)', fontweight='bold', fontsize=12)
plt.xlabel('Model Predicted', fontsize=11)
plt.ylabel('Actually Had', fontsize=11)

# Accuracy visualization
plt.subplot(1, 2, 2)
categories = ['Correct\nPredictions', 'Wrong\nPredictions']
values = [cm[0,0] + cm[1,1], cm[0,1] + cm[1,0]]
colors = ['green', 'red']
plt.bar(categories, values, color=colors, alpha=0.7)
plt.title(f'Model Performance\n{accuracy7*100:.1f}% Accurate', fontweight='bold', fontsize=12)
plt.ylabel('Number of Patients', fontsize=11)

plt.tight_layout()
plt.show()

# %% [markdown]
# # test on new patients

# %%
# Show some predictions vs reality with confidence
print(f"\nLet's check some predictions with confidence:")
print("Patient | Actual      | Skill Morph Predicted | Confidence | Correct?")
print("-" * 70)

for i in range(10):
    actual = "Malignant" if y_test.iloc[i] == 1 else "Benign"
    predicted = "Malignant" if predictions7[i] == 1 else "Benign"
    confidence = prediction_probabilities7[i] * 100 if predictions[i] == 1 else (1 - prediction_probabilities7[i]) * 100
    correct = "✅" if y_test.iloc[i] == predictions7[i] else "❌"
    print(f"{i+1:7} | {actual:11} | {predicted:17} | {confidence:8.1f}%  | {correct}")
# Out:
# Let's check some predictions with confidence:
# Patient | Actual      | Skill Morph Predicted | Confidence | Correct?
# ----------------------------------------------------------------------
#       1 | Benign      | Benign            |    100.0%  | ✅
#       2 | Malignant   | Benign            |    100.0%  | ❌
#       3 | Malignant   | Malignant         |    100.0%  | ✅
#       4 | Benign      | Benign            |    100.0%  | ✅
#       5 | Malignant   | Malignant         |    100.0%  | ✅
#       6 | Malignant   | Malignant         |    100.0%  | ✅
#       7 | Malignant   | Malignant         |    100.0%  | ✅
#       8 | Benign      | Benign            |    100.0%  | ✅
#       9 | Benign      | Benign            |      0.0%  | ✅
#      10 | Malignant   | Malignant         |    100.0%  | ✅

# %%
print('The best depth is 7')
# Out:
# The best depth is 7

# %% [markdown]
# # Use best depth to calculate precision

# %%
precision = precision_score(y_test, predictions7)
print(f"Precision: {precision*100:.1f}")
# Out:
# Precision: 93.3

# %% [markdown]
# # Use best depth to calculate recall

# %%
recall = recall_score(y_test, predictions7)
print(f"Recall: {recall*100:.1f}")
# Out:
# Recall: 87.5

# %% [markdown]
# # Use best depth to calculate f1

# %%
f1 = f1_score(y_test, predictions7)
print(f"F1 score: {f1*100:.1f}")
# Out:
# F1 score: 90.3

# %% [markdown]
# # Detailed metrics visualization

# %%
plt.figure(figsize=(15, 5))

# Subplot 1: Metrics comparison
plt.subplot(1, 2, 1)
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
values = [accuracy, precision, recall, f1]
colors = ['blue', 'green', 'orange', 'red']
bars = plt.bar(metrics, values, color=colors, alpha=0.7)
plt.ylim(0, 1)
plt.title('Performance Metrics Comparison', fontweight='bold', fontsize=12)
plt.ylabel('Score (0-1)', fontsize=11)


# Add benchmark line
plt.axhline(y=0.9, color='red', linestyle='--', alpha=0.5, label='90% Benchmark')
plt.legend()
plt.xticks(rotation=0)



# Subplot 2: Precision vs Recall visualization
plt.subplot(1, 2, 2)
# Create a simple precision-recall visualization
categories = ['True\nPositives', 'False\nPositives', 'False\nNegatives', 'True\nNegatives']
tp, fp, fn, tn = cm[1,1], cm[0,1], cm[1,0], cm[0,0]
counts = [tp, fp, fn, tn]
colors_pr = ['green', 'orange', 'red', 'lightblue']
bars_pr = plt.bar(categories, counts, color=colors_pr, alpha=0.7)
plt.title('Prediction Breakdown', fontweight='bold', fontsize=12)
plt.ylabel('Number of Patients', fontsize=11)

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
